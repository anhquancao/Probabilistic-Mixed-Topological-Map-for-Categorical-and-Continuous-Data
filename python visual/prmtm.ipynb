# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
contData = pd.read_csv("./src/resources/d31/d31.csv", sep=',',names=['x', 'y'] )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-aedb3b77d47d> in <module>()
# ----> 1 contData = pd.read_csv("./src/resources/d31/d31.csv", sep=',',names=['x', 'y'] )
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
contData.head()
# Out:
#          x       y
# 1  25.0514  5.7475
# 2  26.6614  7.3414
# 3  25.2653  6.2466
# 4  25.2285  4.7447
# 5  25.7529  5.1564

# %%
dataSize = 3000
contData = contData.iloc[:dataSize,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fb1adee6eded> in <module>()
#       1 dataSize = 3000
# ----> 2 contData = contData.iloc[:dataSize,:]
#
# NameError: name 'contData' is not defined

# %%
pwd
# Out:
# '/home/quan/code/prmtm/python visual'

# %%
probs = []
items=[]
labels=[]
epsilons=[]
iters=[]
for i in range(0,int(30/2)):
    i = i * 2
    iters.append(i)
    prob = pd.read_csv("../out/bin-normalized-pxc Tue Sep 04 18:46:19 CEST 2018/prob-" + str(i), header=None)
    probs.append(prob)
    item = pd.read_csv("../out/bin-normalized-pxc Tue Sep 04 18:46:19 CEST 2018/items-" + str(i), header=None)
    items.append(item)
    label = pd.read_csv("../out/bin-normalized-pxc Tue Sep 04 18:46:19 CEST 2018/labels-" + str(i), header=None,names=['x','y','label'])
    labels.append(label)
    epsilon = pd.read_csv("../out/bin-normalized-pxc Tue Sep 04 18:46:19 CEST 2018/epsilon" + str(i), 
                          header=None).applymap(lambda x: round(x, 6))
    epsilons.append(epsilon)

# %%
for i in range(len(probs)):
    fig, axes = plt.subplots(nrows=2, ncols=2,figsize=(10,8))
    
    sns.heatmap(probs[i], annot=False, ax=axes[0][0])
    axes[0][0].set_title("iter "+ str(iters[i]) + " p(c)")
    
    
    sns.heatmap(items[i], annot=False, ax=axes[0][1])
    axes[0][1].set_title("iter " +  str(iters[i]) + " Number of items assigned to each cell")
    
    sns.heatmap(epsilons[i], annot=False, ax=axes[1][0])
    axes[1][0].set_title("iter " +  str(iters[i]) + " Epsilon of Bernouli dist")
    
    sns.lmplot(x="x", y="y", data=labels[i], hue='label', fit_reg=False)
# Out:
# /home/quan/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
Czekanowski Dice: 0.17047077470729557
Folkes Mallows: 0.3005305400847464
NMI: 0.5733830253736573
Precision: 0.09348253286490206
Recall: 0.9661548821548821
Rand: 0.6896032010670223

# %%
Silhouette: -0.01549233708643322
Davies Bouldin: 30.894789879675482
